# %%
import pandas as pd
df= pd.read_csv("iris_dataset.csv")
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               NaN
# 2                  NaN               3.2                1.3               0.2
# 3                  4.6               3.1                NaN               0.2
# 4                  5.0               NaN                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  149 non-null    float64
#  1   sepal width (cm)   149 non-null    float64
#  2   petal length (cm)  149 non-null    float64
#  3   petal width (cm)   149 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         149.000000        149.000000         149.000000
# mean            5.851007          3.053691           3.773154
# std             0.825491          0.435040           1.761435
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.400000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        149.000000  150.000000
# mean           1.206040    1.000000
# std            0.760354    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df[['sepal length (cm)']].describe()
# Out:
#        sepal length (cm)
# count         149.000000
# mean            5.851007
# std             0.825491
# min             4.300000
# 25%             5.100000
# 50%             5.800000
# 75%             6.400000
# max             7.900000

# %%
df[['sepal width (cm)', 'sepal width (cm)']]
# Out:
#      sepal width (cm)  sepal width (cm)
# 0                 3.5               3.5
# 1                 3.0               3.0
# 2                 3.2               3.2
# 3                 3.1               3.1
# 4                 NaN               NaN
# ..                ...               ...
# 145               3.0               3.0
# 146               2.5               2.5
# 147               3.0               3.0
# 148               3.4               3.4
# 149               3.0               3.0
#
# [150 rows x 2 columns]

# %%
df.loc[:, "sepal width (cm)"]
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      NaN
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal width (cm), Length: 150, dtype: float64

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()
